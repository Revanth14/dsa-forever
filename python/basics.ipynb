# %%
name = "Python"
print(name)
# Out:
# Python

# %%
len(name)
# Out:
# 6

# %%
lan = "Language"
lan[3:]
# Out:
# 'guage'

# %%
num = 12
arr = [2,4,12,3,55,66]

def first_occurance(num, arr):
    for i in range(len(arr)):
        if arr[i]==num:
            return i+1
    else:
        return -1

first_occurance(num=num, arr=arr)
# Out:
# 3

# %%
print(list("machine"))
print(set("machine"))
# Out:
# ['m', 'a', 'c', 'h', 'i', 'n', 'e']
# {'c', 'a', 'h', 'e', 'i', 'n', 'm'}

# %%
if len(list("machine"))==len(list(set("machine"))):
    print("true")
else:
    print("false")
# Out:
# true
